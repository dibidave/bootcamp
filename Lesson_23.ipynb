# %%
import numpy
import pandas
import scipy.stats

import scipy.special

import bokeh.io
import bokeh.plotting

import iqplot

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
x = numpy.random.uniform(low=0, high=1, size=10000)

figure = iqplot.ecdf(x)

figure.line(
    x=[0, 1],
    y=[0, 1]
)

bokeh.io.show(figure)
# Out:
#   <div class="bk-root" id="e6d56977-c3b8-4d1c-915f-1a7cec6a60fb" data-root-id="1734"></div>
